# %% [markdown]
# # ENIF 2021 Estadisticas descriptivas

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import os

# %%
ENIF_2021=pd.read_csv('Data/ENIF2021_OZMO.csv')
Jovenes=pd.read_csv('Data/ENIF2021_OZMOJovenes.csv')

# %%
cols_demos=['NSE_AMAI','sexo','Nivel_Ingresos','tloc','edad','Grupos_edad','ocupacion','Sector_economia',
            'Escolaridad']

# %%
ENIF_2021[cols_demos].head()
# Out:
#    NSE_AMAI  sexo  Nivel_Ingresos  tloc  edad  Grupos_edad  ocupacion  \
# 0         2     0               0     1    83            0        0.0
# 1         4     0               1     1    20            1        2.0
# 2         6     1               3     1    29            1        2.0
# 3         5     0               0     1    56            0        1.0
# 4         4     0               2     1    37            0        2.0
#
#    Sector_economia  Escolaridad
# 0                0            0
# 1                1            6
# 2                1            8
# 3                0            3
# 4                1            8

# %%
#COLORES

#https://coolors.co/gradient-palette/ee3a3a-ffffff?number=6

paleta_ozmo=['#ee3a3a','#454545','#444ee6','#01f1ba']
paleta_ozmo2=['#ee3a3a','#454545','#444ee6','#01f1ba','#F58E8E','#959595']
paleta_bin_ozmo=['#ee3a3a','#454545']
paleta_red_deg=['#EE3A3A','#F05656','#F37272','#F58E8E','#F8ABAB','#FAC7C7','#FDE3E3']
paleta_gray_deg=['#454545', '#606060', '#7A7A7A', '#959595', '#AFAFAF', '#CACACA', '#E4E4E4']
paleta_blue_deg=["#444EE6","#5F67EA","#7981ED","#949AF1","#AFB3F4","#CACCF8","#E4E6FB"]
paleta_green_deg=["#01F1BA","#2BF3C6","#56F6D1","#80F8DD","#AAFAE8","#D5FDF4","#FFFFFF"]


paleta_red_bin=['#EE3A3A','#F8ABAB']
paleta_blue_bin=["#444EE6","#AFB3F4"]

paleta_red_deg_4=['#EE3A3A','#F37272','#F8ABAB','#FDE3E3']
paleta_gray_deg_4=['#454545', '#7A7A7A',  '#AFAFAF', '#E4E4E4']
paleta_blue_deg_4=["#444EE6","#7981ED","#AFB3F4","#E4E6FB"]
paleta_green_deg_4=["#01F1BA","#56F6D1","#AAFAE8","#D5FDF4"]

# %%
plt.rcParams['font.size']=13

# %%
fig = plt.figure(1, figsize=(7, 7))
ind=np.arange(2)

edad_graph=ENIF_2021['Grupos_edad'].value_counts().plot(kind='bar',color=paleta_bin_ozmo, rot=0)
edad_graph.set_xticks(ind, labels=['Mas de 34 años', 'Edad objetivo'])
plt.ylabel('Conteo')
plt.text(-.05, 8000, '65%',color='w',fontweight="bold")
plt.text(.95, 4000, '35%',color='w',fontweight="bold")
plt.savefig('/home/juanpalms/Desktop/ozmo/Results/Graficas/Edad_POBG.png', dpi=300,bbox_inches="tight")
;
print((ENIF_2021['Grupos_edad'].value_counts()/ENIF_2021['Grupos_edad'].count())*100)
print(ENIF_2021['Grupos_edad'].value_counts())
# Out:
# 0    65.124686
# 1    34.875314
# Name: Grupos_edad, dtype: float64
# 0    8827
# 1    4727
# Name: Grupos_edad, dtype: int64

# %%
fig = plt.figure(1, figsize=(7, 7))
ind=np.arange(2)

sexo_graph=ENIF_2021['sexo'].value_counts().plot(kind='bar',color=paleta_bin_ozmo, rot=0)
sexo_graph.set_xticks(ind, labels=['Mujer', 'Hombre'])
plt.ylabel('Conteo')
plt.text(-.05, 6800, '54%',color='w',fontweight="bold")
plt.text(.95, 5900, '45%',color='w',fontweight="bold")
plt.savefig('/home/juanpalms/Desktop/ozmo/Results/Graficas/Sexo_POBG.png', dpi=300,bbox_inches="tight")
;
print((ENIF_2021['sexo'].value_counts()/ENIF_2021['sexo'].count())*100)
print(ENIF_2021['sexo'].value_counts())
# Out:
# 0    54.190645
# 1    45.809355
# Name: sexo, dtype: float64
# 0    7345
# 1    6209
# Name: sexo, dtype: int64

# %%
print (ENIF_2021['NSE_AMAI'].value_counts())
# Out:
# 2    3915
# 4    2548
# 3    2215
# 5    1759
# 1    1442
# 6    1201
# 7     474
# Name: NSE_AMAI, dtype: int64

# %%
#NO BINARIOS
fig = plt.figure(1, figsize=(7, 7))
labels = ["E","D","D+","C-","C","C+","A/B"]
AMAI_COUNTS = [1442, 3915, 2215, 2548, 1759,1201,474]
print([1442/13554, 3915/13554, 2215/13554, 2548/13554, 1759/13554,1201/13554,474/13554])

plt.bar(labels,AMAI_COUNTS, color=paleta_gray_deg)
plt.ylabel('Conteo')
plt.text(-.35, 1000, '11%',color='w',fontweight="bold")
plt.text(.70,3400, '29%',color='w',fontweight="bold")
plt.text(1.70,1715, '16%',color='w',fontweight="bold")
plt.text(2.65,2015, '19%',color='w',fontweight="bold")
plt.text(3.65,1259, '13%',color='w',fontweight="bold")
plt.text(4.75,700, '9%',color='w',fontweight="bold")
plt.text(5.70,100, '3%',color='black',fontweight="bold")
plt.savefig('/home/juanpalms/Desktop/ozmo/Results/Graficas/AMAI_POBG.png', dpi=300,bbox_inches="tight")

# Add some text for labels, title and custom x-axis tick labels, etc.


plt.show()
# Out:
# [0.1063892577836801, 0.28884462151394424, 0.16342039250405785, 0.18798878559834736, 0.12977718754611184, 0.08860852884757267, 0.03497122620628597]

# %%
#ENIF_2021['Nivel_Ingresos'].value_counts()
#(ENIF_2021['Nivel_Ingresos'].value_counts()/ENIF_2021['Nivel_Ingresos'].count())*100

# %%
#NO BINARIOS
fig = plt.figure(1, figsize=(11, 8))
labels = ['Sin ingresos\n reportados',"Ingresos menores\n a 5,000 MXN\n  mensuales ",
          "Ingresos entre\n 5,000 y 13,000 MXN\n mensuales","Ingresos mayores\n a 13,000 MXN\n mensuales"]

### Dict_ingresos={"Sin ingresos reportados":0,"Ingresos menores a 5k":1, "Ingresos entre 5k y 13k":2,
#                  "Ingresos mayores a 13k":3}
NIV_COUNTS = [5311, 3346,3946, 951]


plt.bar(labels,NIV_COUNTS, color=paleta_blue_deg_4)
plt.ylabel('Conteo')
plt.text(-.15, 4800, '39%',color='w',fontweight="bold")
plt.text(.90,2850, '24%',color='w',fontweight="bold")
plt.text(1.85,3400, '29%',color='w',fontweight="bold")
plt.text(2.9,400, '7%',color='black',fontweight="bold")

plt.savefig('/home/juanpalms/Desktop/ozmo/Results/Graficas/NIVING_POBG.png', dpi=300,bbox_inches="tight")

# Add some text for labels, title and custom x-axis tick labels, etc.


plt.show()

# %%
#ENIF_2021['ocupacion'].value_counts()
#(ENIF_2021['ocupacion'].value_counts()/ENIF_2021['Nivel_Ingresos'].count())*100

# %%
#NO BINARIOS
fig = plt.figure(1, figsize=(12.5, 8))
labels = ["Empleada(o) u\n obrera(o)", "No trabaja","Trabajador(a)\n independiente",
          "Trabajador(a) en\n negocio familiar", "Jornaler(a) o\n peón(a)", "patrón(a) o\n empleador(a)"]

### Dict_ingresos={"Sin ingresos reportados":0,"Ingresos menores a 5k":1, "Ingresos entre 5k y 13k":2,
#                  "Ingresos mayores a 13k":3}
OCU_COUNTS = [5510, 3990,2618,683,581,172]


plt.bar(labels,OCU_COUNTS, color=paleta_green_deg_4)
plt.ylabel('Conteo')
plt.text(-.15, 5000, '40%',color='black',fontweight="bold")
plt.text(.90,3500, '29%',color='black',fontweight="bold")
plt.text(1.85,2100, '19%',color='black',fontweight="bold")
plt.text(2.9,750, '5%',color='black',fontweight="bold")
plt.text(3.9,650, '4%',color='black',fontweight="bold")
plt.text(4.9,200, '1%',color='black',fontweight="bold")

plt.savefig('/home/juanpalms/Desktop/ozmo/Results/Graficas/OCUPACION_POBG.png', dpi=300,bbox_inches="tight")

# Add some text for labels, title and custom x-axis tick labels, etc.


plt.show()

# %%
#ENIF_2021['tloc'].value_counts()
#(ENIF_2021['tloc'].value_counts()/ENIF_2021['tloc'].count())*100
# Out:
# 1    6584
# 4    3148
# 2    1981
# 3    1841
# Name: tloc, dtype: int64

# %%
#NO BINARIOS
fig = plt.figure(1, figsize=(12.5, 8))
labels = ["100,000 o más\n habitantes", "15,000 a 99,999\n habitantes","2,500 a 14,999\n habitantes",
          "Menos de 2,500\n habitantes"]

### Dict_ingresos={"Sin ingresos reportados":0,"Ingresos menores a 5k":1, "Ingresos entre 5k y 13k":2,
#                  "Ingresos mayores a 13k":3}
LOC_COUNTS = [6584, 1981,1841,3148]


plt.bar(labels,LOC_COUNTS, color=paleta_red_deg_4)
plt.ylabel('Conteo')
plt.text(-.15, 6100, '40%',color='black',fontweight="bold")
plt.text(.90,1480, '29%',color='black',fontweight="bold")
plt.text(1.85,1400, '19%',color='black',fontweight="bold")
plt.text(2.9,2800, '5%',color='black',fontweight="bold")


plt.savefig('/home/juanpalms/Desktop/ozmo/Results/Graficas/LOC_POBG.png', dpi=300,bbox_inches="tight")

# Add some text for labels, title and custom x-axis tick labels, etc.


plt.show()

# %%
ENIF_2021['p3_1_1'].value_counts()
#(ENIF_2021['p3_1_1'].value_counts()/ENIF_2021['p3_1_1'].count())*100
# Out:
# 3    26.346466
# 2    21.963996
# 6    20.163789
# 8    19.986720
# 0     5.098126
# 7     2.324037
# 9     1.918253
# 4     1.866608
# 5     0.258226
# 1     0.073779
# Name: p3_1_1, dtype: float64

# %%
#NO BINARIOS
fig = plt.figure(1, figsize=(18, 8))
labels = ["Ninguno", "Preescolar o\n kinder","Primaria", "Secundaria", "Estudios\n técnicos con\n secundaria",
          "Preparatoria o\n bachillerato", "Estudios\n técnicos con\n preparatoria", "Licenciatura o\n ingeniería\n(profesional)",
             "Maestría o\n doctorado"]

### Dict_ingresos={"Sin ingresos reportados":0,"Ingresos menores a 5k":1, "Ingresos entre 5k y 13k":2,
#                  "Ingresos mayores a 13k":3}
COUNTS = [691, 10,2977,3571, 253,2733,350,2709,260]


plt.bar(labels,COUNTS, color=paleta_gray_deg_4)
plt.ylabel('Conteo')
plt.text(-.15, 200, '5%',color='w',fontweight="bold")
plt.text(.90,200, '1%',color='black',fontweight="bold")
plt.text(1.85,2500, '21%',color='black',fontweight="bold")
plt.text(2.9,3100, '26%',color='black',fontweight="bold")
plt.text(3.9,350, '2%',color='black',fontweight="bold")
plt.text(4.9,2400, '20%',color='black',fontweight="bold")
plt.text(5.9,450, '3%',color='black',fontweight="bold")
plt.text(6.9,2400, '20%',color='black',fontweight="bold")
plt.text(7.9,350, '2%',color='black',fontweight="bold")





plt.savefig('/home/juanpalms/Desktop/ozmo/Results/Graficas/ESTUDIOS_POBG.png', dpi=300,bbox_inches="tight")

# Add some text for labels, title and custom x-axis tick labels, etc.


plt.show()

# %%
#ENIF_2021['Sector_economia'].value_counts()
(ENIF_2021['Sector_economia'].value_counts()/ENIF_2021['Sector_economia'].count())*100
# Out:
# 2    37.103438
# 0    34.476907
# 1    28.419655
# Name: Sector_economia, dtype: float64

# %%
#NO BINARIOS
fig = plt.figure(1, figsize=(8, 8))
labels = ["Trabajador\n formal","Trabajador\n informal"]


LOC_COUNTS = [3852,5029]


plt.bar(labels,LOC_COUNTS, color=paleta_blue_bin)
plt.ylabel('Conteo')
plt.text(-.1,3300, '37%',color='w',fontweight="bold")
plt.text(.90,4600, '28%',color='black',fontweight="bold")





plt.savefig('/home/juanpalms/Desktop/ozmo/Results/Graficas/SECTOR_POBG.png', dpi=300,bbox_inches="tight")

# Add some text for labels, title and custom x-axis tick labels, etc.


plt.show()

# %%
Jovenes['Sector_economia'].value_counts()
# Out:
# 2    1794
# 1    1556
# 0    1377
# Name: Sector_economia, dtype: int64

# %%
#NO BINARIOS grouped
fig = plt.figure(1, figsize=(5, 5))
gs = gridspec.GridSpec(6,2)
gs.update(wspace=0.2, hspace=0.25)


fig = plt.figure(1, figsize=(8, 8))
labels = ["Trabajador\n formal","Trabajador\n informal"]


COUNT1 = [3852,5029]
COUNT2 = [3852,5029]

plt.bar(labels,LOC_COUNTS, color=paleta_blue_bin)
plt.ylabel('Conteo')
plt.text(-.1,3300, '37%',color='w',fontweight="bold")
plt.text(.90,4600, '28%',color='black',fontweight="bold")





plt.savefig('/home/juanpalms/Desktop/ozmo/Results/Graficas/SECTOR_POBG.png', dpi=300,bbox_inches="tight")

# Add some text for labels, title and custom x-axis tick labels, etc.


plt.show()

# %%
#NO BINARIOS grouped

fig = plt.figure(1, figsize=(5, 5))
gs = gridspec.GridSpec(6,2)
gs.update(wspace=0.2, hspace=0.25)




#Generate first panel
#remember, the grid spec is rows, then columns
jovenesBdP_subsplot= fig.add_subplot(gs[0:6,0:1])

plt.bar(x90, y90, linestyle='none', marker='^', label='90', 
         color=colors[0], mfc='w', markersize=8)

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
